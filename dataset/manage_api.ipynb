# %%
# !pip install beautifulsoup4 lxml

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt


url = 'http://openapi.q-net.or.kr/api/service/rest/InquiryTestInformationNTQSVC/getJMList'
params ={'serviceKey' : 'iBnhEtxdvRgWB11T/LDEYLkaJ4HMmCecarGXtMain7K20fr/7JhIxc1Q6VYvXE9SzOGXjcCYgr22eBhvAxxtxA==', 'jmcd' : '1320' }

response = requests.get(url, params=params)
items = soup.find_all('item')
data = {'column1': [], 'column2': []}  # 필요한 컬럼으로 구성된 딕셔너리

for item in items:
    data['column1'].append(item.find('column1Tag').text)
    data['column2'].append(item.find('column2Tag').text)

df = pd.DataFrame(data)

# 시각화
plt.figure(figsize=(10, 5))
plt.plot(df['column1'], df['column2'])
plt.title('Data Visualization')
plt.xlabel('Column 1')
plt.ylabel('Column 2')
plt.show()


print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items/></body></response>'
